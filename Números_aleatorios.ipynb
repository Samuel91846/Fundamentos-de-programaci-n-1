# %%
import random

# %%
CR=0
N=0
ASTN=0
ASP=0
ASNN=0
Cantidad_Numeros = int(input(' Cantidad de números: '))
# Out:
#  Cantidad de números: 10

# %%
while CR<100:
  N= random.randint(-100, 100)
  print(' Número: ', N)
  ASTN = ASTN+N
  if N>0:
    ASNP=ASP+N
  else:
      ASNN=ASNN+N
      CR=CR+1
# Out:
#  Número:  100
#  Número:  -100
#  Número:  55
#  Número:  63
#  Número:  -16
#  Número:  -42
#  Número:  40
#  Número:  -61
#  Número:  45
#  Número:  -25
#  Número:  89
#  Número:  -23
#  Número:  50
#  Número:  72
#  Número:  4
#  Número:  51
#  Número:  59
#  Número:  -88
#  Número:  -96
#  Número:  66
#  Número:  49
#  Número:  -48
#  Número:  -84
#  Número:  -45
#  Número:  71
#  Número:  17
#  Número:  15
#  Número:  25
#  Número:  -73
#  Número:  -88
#  Número:  49
#  Número:  8
#  Número:  -92
#  Número:  69
#  Número:  9
#  Número:  -55
#  Número:  -73
#  Número:  24
#  Número:  -19
#  Número:  45
#  Número:  26
#  Número:  55
#  Número:  17
#  Número:  88
#  Número:  -61
#  Número:  -19
#  Número:  -11
#  Número:  -23
#  Número:  -19
#  Número:  -28
#  Número:  -55
#  Número:  -80
#  Número:  20
#  Número:  66
#  Número:  16
#  Número:  -81
#  Número:  28
#  Número:  -48
#  Número:  39
#  Número:  89
#  Número:  79
#  Número:  81
#  Número:  28
#  Número:  79
# ...

# %%
print(' Suma todos: ', ASTN)
print(' Suma positivos: ', ASP)
print(' Suma negativos: ', ASNN)
# Out:
#  Suma todos:  13
#  Suma positivos:  0
#  Suma negativos:  -4957
